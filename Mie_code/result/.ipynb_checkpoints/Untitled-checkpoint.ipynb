# %%
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# %%
# Adjusting the loading process to handle potential formatting issues
def clean_and_load_data(file_path):
    # Read the file content
    with open(file_path, 'r') as file:
        lines = file.readlines()
    
    # Clean and prepare data
    cleaned_data = []
    for line in lines:
        # Strip trailing newline and split by tabs
        split_line = line.strip().split('\t')
        # Remove any empty strings
        cleaned_values = [float(value) for value in split_line if value]
        cleaned_data.append(cleaned_values)
    
    return np.array(cleaned_data)

# %%
new_data = glob('*.dat')
new_data.sort()

old_data = glob('old/*.dat')
old_data.sort()

lam_old = 10**(np.arange(-1,2.01,0.01))
NLAMBDA = 16000.
LAMBDA_HIGH = 200*1.e-6
LAMBDA_LOW = 0.1*1.e-6
dlambda = (np.log10(200*1.e-6)-np.log10(0.1*1.e-6))/(NLAMBDA-1)
lam_new = 10**(np.arange(np.log10(LAMBDA_LOW), np.log10(LAMBDA_HIGH)+dlambda*0.1, dlambda))*1.e+6

size = 10**(np.arange(-3, 2.01, 0.25))
print(size)
print(len(size))
for idata in np.arange(3):  # albedo, cross, geo

    data1 = clean_and_load_data(old_data[idata])
    data2 = clean_and_load_data(new_data[idata])                            


#  the first column is wavelengths and the rest are data values
    lam_old = data1[:,0]  # First column as wavelengths
    lam_new = data2[:,0]
    var_old = data1[:,1:]
    var_new = data2[:,1:]

    fig = plt.figure(figsize=(10, 8))
# Create the heatmap
    ax = fig.add_subplot(121)
    ax.contourf(size, lam_old, var_old, cmap='viridis')
    ax.set_ylim([0.1,200])
    ax = fig.add_subplot(122)
    ax.contourf(size, lam_new, var_new, cmap='viridis')
    ax.set_ylim([0.1,200])
    plt.colorbar()
    plt.show()
# Out:
# [1.00000000e-03 1.77827941e-03 3.16227766e-03 5.62341325e-03
#  1.00000000e-02 1.77827941e-02 3.16227766e-02 5.62341325e-02
#  1.00000000e-01 1.77827941e-01 3.16227766e-01 5.62341325e-01
#  1.00000000e+00 1.77827941e+00 3.16227766e+00 5.62341325e+00
#  1.00000000e+01 1.77827941e+01 3.16227766e+01 5.62341325e+01
#  1.00000000e+02]
# 21
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 35
#      33 ax.set_ylim([0.1,200])
#      34 ax = fig.add_subplot(122)
# ---> 35 ax.contourf(size, lam_new, var_new, cmap='viridis')
#      36 ax.set_ylim([0.1,200])
#      37 plt.colorbar()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6536, in Axes.contourf(self, *args, **kwargs)
#    6527 """
#    6528 Plot filled contours.
#    6529
#    (...)
#    6533 %(contour_doc)s
#    6534 """
#    6535 kwargs['filled'] = True
# -> 6536 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6537 self._request_autoscale_view()
#    6538 return contours
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py:858, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     854 if self.negative_linestyles is None:
#     855     self.negative_linestyles = \
#     856         mpl.rcParams['contour.negative_linestyle']
# --> 858 kwargs = self._process_args(*args, **kwargs)
#     859 self._process_levels()
#     861 self._extend_min = self.extend in ['min', 'both']
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py:1523, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1520         corner_mask = mpl.rcParams['contour.corner_mask']
#    1521 self._corner_mask = corner_mask
# -> 1523 x, y, z = self._contour_args(args, kwargs)
#    1525 contour_generator = contourpy.contour_generator(
#    1526     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1527     line_type=contourpy.LineType.SeparateCode,
#    1528     fill_type=contourpy.FillType.OuterCode,
#    1529     chunk_size=self.nchunk)
#    1531 t = self.get_transform()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py:1563, in QuadContourSet._contour_args(self, args, kwargs)
#    1561 elif 2 < nargs <= 4:
#    1562     x, y, z_orig, *args = args
# -> 1563     x, y, z = self._check_xyz(x, y, z_orig, kwargs)
#    1565 else:
#    1566     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py:1602, in QuadContourSet._check_xyz(self, x, y, z, kwargs)
#    1600 ny, = y.shape
#    1601 if nx != Nx:
# -> 1602     raise TypeError(f"Length of x ({nx}) must match number of "
#    1603                     f"columns in z ({Nx})")
#    1604 if ny != Ny:
#    1605     raise TypeError(f"Length of y ({ny}) must match number of "
#    1606                     f"rows in z ({Ny})")
#
# TypeError: Length of x (21) must match number of columns in z (20)

# %%
var_old.shape
# Out:
# (301, 21)

# %%
new_data
# Out:
# ['Albedo_water_110123.dat', 'Cross_water_110123.dat', 'Geo_water_110123.dat']

# %%
old_data
# Out:
# ['old/Albedo_water_110123.dat',
#  'old/Cross_water_110123.dat',
#  'old/Geo_water_110123.dat']
